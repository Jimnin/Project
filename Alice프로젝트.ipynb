# %% [markdown]
# # **위성 데이터를 이용하여 과학 데이터 재생산**

# %% [markdown]
# ## 프로젝트 목표
#
# 1.   딥러닝을 이용하여 위성 데이터 이진분류
#
# 2.   위성 데이터를 이용하여 과학적인 데이터 재생산

# %% [markdown]
# ## 프로젝트 개요
# 지구 근처에서의 플라즈마 상태를 정확히 파악하는 것은 우주환경 예보에서 중요한 역할입니다. 하지만 태양에서 불어오는 태양풍과 지구 자기장의 상호작용으로 생각보다 복잡하고 비선형적인 변화를 야기합니다.
#
# 때문에 우주환경을 위한 위성에서는 많은 기기를 탑재하고 따라서 많은 비용이 발생합니다. 이번 프로젝트에서는 단순히 태양풍 플라즈마의 상태를 나타내는 데이터를 이용하여 과학적으로 의미가 있는 이온의 비율을 나타내는 데이터로 재생산하는 모델을 구성합니다.
#
# 더 나아가 좋은 결과가 나온다면 현재 진행하고 있는 저의 석사 연구에도 적용하여 좀 더 진행 해볼 예정입니다.

# %% [markdown]
# ## 1. 라이브러리 불러오기

# %%
# 구글 코랩을 이용하여 프로젝트 진행
from google.colab import drive

# 드라이브 마운트
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 텐서플로우 애드온 추가
# !pip install tensorflow-addons

# 시드와 경로 변경을 위한 라이브러리
import os,sys, random

# 경로 변경
os.chdir('drive/MyDrive/Alice프로젝트')
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 10.6 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix

import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import colors
from datetime import datetime, timedelta

# %% [markdown]
# ## 2. 데이터 전처리

# %% [markdown]
# 2.1. Heliopy 라이브러리를 이용하여 데이터를 미리 다운로드하여 "ace_1998.csv","ace_1999.csv","ace_2000.csv"로 데이터를 구성합니다.

# %% [markdown]
# 2.2. 1998년 데이터만 info, head를 통해 대략적인 데이터를 파악합니다.

# %% [markdown]
# 2.3. resample 메서드를 이용하여 1시간으로 평균 데이터를 구성하고 "1hour_ace_1998.csv","1hour_ace_1999.csv","1hour_ace_2000.csv"로 저장합니다.

# %%
csv_list = ["ace_1998.csv","ace_1999.csv","ace_2000.csv"]

for name in csv_list:
  year = name[4:8]
  df = pd.read_csv(name,index_col='Time',parse_dates=True)

  if int(year) == 1998:
    print(df.info())
    print(df.head(5))
  else:
    pass

  averge = df.resample('1H').mean()

#  averge.to_csv("1hour_"+name)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 529556 entries, 1998-01-01 00:00:00 to 1998-12-31 23:39:59
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Magnitude   517701 non-null  float64
#  1   BRTN_0      517701 non-null  float64
#  2   BRTN_1      517701 non-null  float64
#  3   BRTN_2      517701 non-null  float64
#  4   Np          384961 non-null  float64
#  5   Vp          405656 non-null  float64
#  6   Tpr         384809 non-null  float64
#  7   V_RTN_0     404694 non-null  float64
#  8   V_RTN_1     404694 non-null  float64
#  9   V_RTN_2     404694 non-null  float64
#  10  C6to5       6381 non-null    float64
#  11  C6to5_qual  7903 non-null    float64
#  12  O7to6       6418 non-null    float64
#  13  O7to6_qual  7903 non-null    float64
#  14  SW_type     7903 non-null    float64
# dtypes: float64(15)
# memory usage: 64.6 MB
# None
#                      Magnitude    BRTN_0    BRTN_1  ...  O7to6  O7to6_qual  SW_type
# Time                                                ...
# 1998-01-01 00:00:00   3.738950  2.424183  0.660150  ...    NaN         NaN      NaN
# 1998-01-01 00:01:00   3.123136  2.545750  0.330636  ...    NaN         NaN      NaN
# 1998-01-01 00:02:00   4.560550  0.615800 -0.374100  ...    NaN         NaN      NaN
# 1998-01-01 00:03:00   4.892300  0.939333 -0.160883  ...    NaN         NaN      NaN
# 1998-01-01 00:04:00   5.000983  1.091083  0.170317  ...    NaN         NaN      NaN
#
# [5 rows x 15 columns]

# %% [markdown]
# 2.4.1. 데이터를 불러오고 필요한 변수만을 선택하는 함수를 정의합니다.

# %%
def data_set(file_name):
  df = pd.read_csv(file_name,index_col='Time',parse_dates=True).dropna(axis=0)
  df = df[(df['SW_type'] == 0)|(df['SW_type'] == 1)] 
  df = df[(df['O7to6_qual'] == 0)]

  print(df.head(5))

  k = 8.617*10**(-5);m = 1.67*10**(-24) #g

  # 새로운 변수를 정의합니다. 플라즈마에서 중요한 "엔트로피"라는 변수입니다.
  df['entro'] = (k*df['Tpr'])/df['Np']**(2/3)

  X = df.drop(columns=['C6to5', 'C6to5_qual', 'O7to6', 'O7to6_qual','SW_type'])
  Y = df[['C6to5', 'C6to5_qual', 'O7to6', 'O7to6_qual','SW_type']]
  
  return X,Y

# %% [markdown]
# 2.4.2. confusion matrix를 그려주는 함수를 정의합니다.

# %%
def c_matrix(matrix):
  plt.rcParams['figure.figsize'] = (5, 5)
  sns.set(font_scale = 2)

  ax = sns.heatmap(matrix, annot=True)
  plt.xlabel('Prediction')
  plt.ylabel('Real Data')
  ax.set_xticklabels((0,1))
  ax.set_yticklabels((0,1))
  print(matrix)
  plt.show()

# %% [markdown]
# 2.5. 1998년, 1999년 데이터를 train 데이터로 이용합니다.

# %% [markdown]
# 2.6. train/validation데이터를 8:2로 분리하고, StandardScaler를 통해서 데이터의 스케일을 조정합니다.

# %%
para = ['Magnitude' , 'Np', 'Vp', 'Tpr','entro']
# 차례대로 자기장의 세기, 플라즈마의 밀도, 플라즈마의 속도, 플라즈마의 온도, 엔트로피를 뜻함

train_X_1998, train_Y_1998 = data_set("1hour_ace_1998.csv")
train_X_1999, train_Y_1999 = data_set("1hour_ace_1999.csv")

train_XX = pd.concat([train_X_1998,train_X_1999]);train_YY = pd.concat([train_Y_1998,train_Y_1999])

# 데이터의 전체적인 분포 파악
print(train_YY['SW_type'].value_counts())
train_YY['SW_type'].value_counts().plot(kind='bar')

# 데이터가 0인 경우 : "Streamer Wind", 1인 경우 : "Coronal Hole Wind"로 분류합니다.

# 데이터의 분포를 로그 스케일로 지정
X = np.log10(train_XX[para])
Y = train_YY['SW_type'].astype(int)

# 시드를 고정합니다
SEED = 0
train_X,valid_X,train_Y,valid_Y = train_test_split(X,Y,test_size=0.2, shuffle=True, stratify=Y, random_state=SEED)

sc = StandardScaler()

train_X = sc.fit_transform(train_X)
valid_X = sc.transform(valid_X)
# Out:
#                      Magnitude     BRTN_0  ...  O7to6_qual  SW_type
# Time                                       ...
# 1998-02-05 00:00:00  13.726127 -13.358070  ...         0.0      0.0
# 1998-02-05 02:00:00  13.184360 -12.066559  ...         0.0      0.0
# 1998-02-05 03:00:00  13.028030 -11.595308  ...         0.0      0.0
# 1998-02-05 07:00:00  10.911599  -8.937269  ...         0.0      0.0
# 1998-02-05 08:00:00   9.770036  -7.733318  ...         0.0      0.0
#
# [5 rows x 15 columns]
#                      Magnitude    BRTN_0  ...  O7to6_qual  SW_type
# Time                                      ...
# 1999-01-01 00:00:00   6.792248  1.689462  ...         0.0      1.0
# 1999-01-01 01:00:00   6.883963  4.513463  ...         0.0      1.0
# 1999-01-01 02:00:00   7.074452  3.817440  ...         0.0      0.0
# 1999-01-01 03:00:00   6.644369  3.538510  ...         0.0      1.0
# 1999-01-01 04:00:00   6.644514  3.085313  ...         0.0      1.0
#
# [5 rows x 15 columns]
# 0.0    6719
# 1.0    5770
# Name: SW_type, dtype: int64

# %% [markdown]
# 2.7. test 데이터도 위와 같이 구성해줍니다.

# %%
test_XX, test_YY = data_set("1hour_ace_2000.csv")

test_X = np.log10(test_XX[para])
test_Y = test_YY['SW_type'].astype(int)

test_X = sc.transform(test_X)
# Out:
#                      Magnitude    BRTN_0  ...  O7to6_qual  SW_type
# Time                                      ...
# 2000-01-01 00:00:00   8.013428  5.871203  ...         0.0      1.0
# 2000-01-01 01:00:00   7.627232  3.187808  ...         0.0      1.0
# 2000-01-01 02:00:00   7.617455  3.693550  ...         0.0      1.0
# 2000-01-01 03:00:00   7.146972  2.879958  ...         0.0      1.0
# 2000-01-01 04:00:00   6.753734  4.332838  ...         0.0      1.0
#
# [5 rows x 15 columns]

# %% [markdown]
# ## 3. 데이터 훈련 및 결과

# %% [markdown]
# 3.1. 텐서 플로우 라이브러리 불러오기 및 시드 고정

# %%
import tensorflow as tf
import tensorflow_addons as tfa

tf.random.set_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# 3.2. 배치 사이즈 및 모델 세팅 -> 데이터 훈련

# %%
train_dt = tf.data.Dataset.from_tensor_slices((train_X, train_Y))
train_dt = train_dt.shuffle(len(train_X)).batch(batch_size=256)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, input_dim=5, activation='relu'),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
    ])

# %%
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
history = model.fit(train_dt, epochs=50, verbose=2,validation_data=(valid_X,valid_Y))
# Out:
# Epoch 1/50
# 40/40 - 2s - loss: 0.5264 - accuracy: 0.7785 - val_loss: 0.5014 - val_accuracy: 0.7870 - 2s/epoch - 38ms/step
# Epoch 2/50
# 40/40 - 0s - loss: 0.4846 - accuracy: 0.7814 - val_loss: 0.4721 - val_accuracy: 0.7878 - 476ms/epoch - 12ms/step
# Epoch 3/50
# 40/40 - 0s - loss: 0.4680 - accuracy: 0.7857 - val_loss: 0.4627 - val_accuracy: 0.7898 - 469ms/epoch - 12ms/step
# Epoch 4/50
# 40/40 - 0s - loss: 0.4613 - accuracy: 0.7886 - val_loss: 0.4545 - val_accuracy: 0.7914 - 322ms/epoch - 8ms/step
# Epoch 5/50
# 40/40 - 0s - loss: 0.4569 - accuracy: 0.7888 - val_loss: 0.4494 - val_accuracy: 0.7950 - 294ms/epoch - 7ms/step
# Epoch 6/50
# 40/40 - 0s - loss: 0.4537 - accuracy: 0.7896 - val_loss: 0.4451 - val_accuracy: 0.7966 - 328ms/epoch - 8ms/step
# Epoch 7/50
# 40/40 - 0s - loss: 0.4512 - accuracy: 0.7906 - val_loss: 0.4420 - val_accuracy: 0.7986 - 447ms/epoch - 11ms/step
# Epoch 8/50
# 40/40 - 0s - loss: 0.4493 - accuracy: 0.7915 - val_loss: 0.4405 - val_accuracy: 0.7978 - 301ms/epoch - 8ms/step
# Epoch 9/50
# 40/40 - 0s - loss: 0.4473 - accuracy: 0.7924 - val_loss: 0.4358 - val_accuracy: 0.7998 - 327ms/epoch - 8ms/step
# Epoch 10/50
# 40/40 - 0s - loss: 0.4457 - accuracy: 0.7930 - val_loss: 0.4346 - val_accuracy: 0.8022 - 286ms/epoch - 7ms/step
# Epoch 11/50
# 40/40 - 0s - loss: 0.4442 - accuracy: 0.7933 - val_loss: 0.4325 - val_accuracy: 0.8054 - 472ms/epoch - 12ms/step
# Epoch 12/50
# 40/40 - 0s - loss: 0.4432 - accuracy: 0.7935 - val_loss: 0.4321 - val_accuracy: 0.8058 - 451ms/epoch - 11ms/step
# Epoch 13/50
# 40/40 - 0s - loss: 0.4422 - accuracy: 0.7935 - val_loss: 0.4305 - val_accuracy: 0.8042 - 300ms/epoch - 7ms/step
# Epoch 14/50
# 40/40 - 0s - loss: 0.4411 - accuracy: 0.7947 - val_loss: 0.4287 - val_accuracy: 0.8038 - 316ms/epoch - 8ms/step
# Epoch 15/50
# 40/40 - 0s - loss: 0.4404 - accuracy: 0.7942 - val_loss: 0.4294 - val_accuracy: 0.8054 - 323ms/epoch - 8ms/step
# Epoch 16/50
# 40/40 - 0s - loss: 0.4398 - accuracy: 0.7947 - val_loss: 0.4271 - val_accuracy: 0.8070 - 328ms/epoch - 8ms/step
# Epoch 17/50
# 40/40 - 0s - loss: 0.4389 - accuracy: 0.7953 - val_loss: 0.4270 - val_accuracy: 0.8062 - 313ms/epoch - 8ms/step
# Epoch 18/50
# 40/40 - 0s - loss: 0.4383 - accuracy: 0.7948 - val_loss: 0.4253 - val_accuracy: 0.8062 - 338ms/epoch - 8ms/step
# Epoch 19/50
# 40/40 - 1s - loss: 0.4379 - accuracy: 0.7964 - val_loss: 0.4252 - val_accuracy: 0.8062 - 512ms/epoch - 13ms/step
# Epoch 20/50
# 40/40 - 0s - loss: 0.4372 - accuracy: 0.7952 - val_loss: 0.4244 - val_accuracy: 0.8034 - 480ms/epoch - 12ms/step
# Epoch 21/50
# 40/40 - 0s - loss: 0.4367 - accuracy: 0.7968 - val_loss: 0.4239 - val_accuracy: 0.8058 - 403ms/epoch - 10ms/step
# Epoch 22/50
# 40/40 - 1s - loss: 0.4360 - accuracy: 0.7960 - val_loss: 0.4235 - val_accuracy: 0.8074 - 624ms/epoch - 16ms/step
# Epoch 23/50
# 40/40 - 0s - loss: 0.4356 - accuracy: 0.7970 - val_loss: 0.4234 - val_accuracy: 0.8062 - 416ms/epoch - 10ms/step
# Epoch 24/50
# 40/40 - 0s - loss: 0.4348 - accuracy: 0.7973 - val_loss: 0.4225 - val_accuracy: 0.8066 - 370ms/epoch - 9ms/step
# Epoch 25/50
# 40/40 - 1s - loss: 0.4342 - accuracy: 0.7980 - val_loss: 0.4232 - val_accuracy: 0.8078 - 507ms/epoch - 13ms/step
# Epoch 26/50
# 40/40 - 0s - loss: 0.4340 - accuracy: 0.7968 - val_loss: 0.4218 - val_accuracy: 0.8086 - 357ms/epoch - 9ms/step
# Epoch 27/50
# 40/40 - 0s - loss: 0.4333 - accuracy: 0.7976 - val_loss: 0.4216 - val_accuracy: 0.8058 - 327ms/epoch - 8ms/step
# Epoch 28/50
# 40/40 - 0s - loss: 0.4329 - accuracy: 0.7982 - val_loss: 0.4221 - val_accuracy: 0.8086 - 489ms/epoch - 12ms/step
# Epoch 29/50
# 40/40 - 0s - loss: 0.4324 - accuracy: 0.7972 - val_loss: 0.4209 - val_accuracy: 0.8090 - 354ms/epoch - 9ms/step
# Epoch 30/50
# 40/40 - 1s - loss: 0.4320 - accuracy: 0.7981 - val_loss: 0.4215 - val_accuracy: 0.8090 - 583ms/epoch - 15ms/step
# Epoch 31/50
# 40/40 - 0s - loss: 0.4316 - accuracy: 0.7980 - val_loss: 0.4208 - val_accuracy: 0.8098 - 486ms/epoch - 12ms/step
# Epoch 32/50
# 40/40 - 0s - loss: 0.4312 - accuracy: 0.7988 - val_loss: 0.4203 - val_accuracy: 0.8074 - 483ms/epoch - 12ms/step
# Epoch 33/50
# 40/40 - 1s - loss: 0.4309 - accuracy: 0.7976 - val_loss: 0.4204 - val_accuracy: 0.8094 - 514ms/epoch - 13ms/step
# Epoch 34/50
# 40/40 - 1s - loss: 0.4305 - accuracy: 0.7975 - val_loss: 0.4200 - val_accuracy: 0.8082 - 526ms/epoch - 13ms/step
# Epoch 35/50
# 40/40 - 0s - loss: 0.4301 - accuracy: 0.7979 - val_loss: 0.4199 - val_accuracy: 0.8106 - 313ms/epoch - 8ms/step
# Epoch 36/50
# 40/40 - 0s - loss: 0.4298 - accuracy: 0.7992 - val_loss: 0.4194 - val_accuracy: 0.8094 - 357ms/epoch - 9ms/step
# Epoch 37/50
# 40/40 - 0s - loss: 0.4293 - accuracy: 0.7977 - val_loss: 0.4200 - val_accuracy: 0.8090 - 325ms/epoch - 8ms/step
# Epoch 38/50
# 40/40 - 0s - loss: 0.4292 - accuracy: 0.7985 - val_loss: 0.4188 - val_accuracy: 0.8098 - 283ms/epoch - 7ms/step
# Epoch 39/50
# 40/40 - 0s - loss: 0.4287 - accuracy: 0.7984 - val_loss: 0.4189 - val_accuracy: 0.8106 - 286ms/epoch - 7ms/step
# Epoch 40/50
# 40/40 - 0s - loss: 0.4285 - accuracy: 0.7985 - val_loss: 0.4187 - val_accuracy: 0.8094 - 325ms/epoch - 8ms/step
# Epoch 41/50
# 40/40 - 0s - loss: 0.4284 - accuracy: 0.7986 - val_loss: 0.4196 - val_accuracy: 0.8078 - 308ms/epoch - 8ms/step
# Epoch 42/50
# 40/40 - 0s - loss: 0.4282 - accuracy: 0.7994 - val_loss: 0.4182 - val_accuracy: 0.8086 - 456ms/epoch - 11ms/step
# Epoch 43/50
# 40/40 - 0s - loss: 0.4279 - accuracy: 0.7978 - val_loss: 0.4189 - val_accuracy: 0.8106 - 322ms/epoch - 8ms/step
# Epoch 44/50
# 40/40 - 0s - loss: 0.4278 - accuracy: 0.7994 - val_loss: 0.4184 - val_accuracy: 0.8114 - 368ms/epoch - 9ms/step
# Epoch 45/50
# 40/40 - 1s - loss: 0.4274 - accuracy: 0.7976 - val_loss: 0.4199 - val_accuracy: 0.8050 - 509ms/epoch - 13ms/step
# Epoch 46/50
# 40/40 - 1s - loss: 0.4272 - accuracy: 0.7993 - val_loss: 0.4183 - val_accuracy: 0.8090 - 511ms/epoch - 13ms/step
# Epoch 47/50
# 40/40 - 1s - loss: 0.4271 - accuracy: 0.7985 - val_loss: 0.4187 - val_accuracy: 0.8098 - 514ms/epoch - 13ms/step
# Epoch 48/50
# 40/40 - 0s - loss: 0.4268 - accuracy: 0.7992 - val_loss: 0.4184 - val_accuracy: 0.8106 - 248ms/epoch - 6ms/step
# Epoch 49/50
# 40/40 - 0s - loss: 0.4267 - accuracy: 0.7984 - val_loss: 0.4177 - val_accuracy: 0.8106 - 233ms/epoch - 6ms/step
# Epoch 50/50
# 40/40 - 0s - loss: 0.4265 - accuracy: 0.7981 - val_loss: 0.4182 - val_accuracy: 0.8098 - 163ms/epoch - 4ms/step

# %% [markdown]
# 3.3. epoch당 정확도와 loss변화 파악하기

# %%
history = pd.DataFrame(history.history)

fig, acc_ax = plt.subplots(figsize=(15,7))

loss_ax = acc_ax.twinx()

acc_ax.plot(history['accuracy'], color='blue',marker='o',label='train acc')
acc_ax.plot(history['val_accuracy'], color='green',marker='o', label='val acc')

loss_ax.plot(history['loss'], color='yellow',marker='o', label='train loss')
loss_ax.plot(history['val_loss'], color='red',marker='o', label='val loss')

acc_ax.set_xlabel('epoch')
acc_ax.set_ylabel('accuray')
loss_ax.set_ylabel('loss')

acc_ax.legend(loc='upper right')
loss_ax.legend(loc='lower right')

plt.show()

# %% [markdown]
# 3.4. 실제값과 예측값을 비교하기

# %%
loss, acc = model.evaluate(test_X, test_Y)

predictions = model.predict(test_X)

print("테스트 데이터의 Accuracy 값: ", acc)
for i in range(10):
    print("%d 번째 데이터의 [실제값,예측값] : [%d,%d]"\
          % (i, test_Y.iloc[i],np.around(predictions[i])))
# Out:
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4130 - accuracy: 0.8151
# 테스트 데이터의 Accuracy 값:  0.8150742053985596
# 0 번째 데이터의 [실제값,예측값] : [1,1]
# 1 번째 데이터의 [실제값,예측값] : [1,1]
# 2 번째 데이터의 [실제값,예측값] : [1,1]
# 3 번째 데이터의 [실제값,예측값] : [1,1]
# 4 번째 데이터의 [실제값,예측값] : [1,1]
# 5 번째 데이터의 [실제값,예측값] : [1,1]
# 6 번째 데이터의 [실제값,예측값] : [1,1]
# 7 번째 데이터의 [실제값,예측값] : [1,1]
# 8 번째 데이터의 [실제값,예측값] : [1,1]
# 9 번째 데이터의 [실제값,예측값] : [1,1]

# %%
d_cm = confusion_matrix(test_Y, np.around(predictions))

c_matrix(d_cm)
# Out:
# [[2559  564]
#  [ 545 2329]]

# %%
fig,ax = plt.subplots(1,3,figsize=(15,5))

tftf = (test_YY['SW_type'] == np.around(predictions).flatten())

ax[0].scatter(test_XX['Vp'],test_XX['entro'],c=test_YY['SW_type'],cmap='bwr',alpha=0.5)
ax[1].scatter(test_XX['Vp'],test_XX['entro'],c=np.around(predictions),cmap='bwr',alpha=0.5)
ax[2].scatter(test_XX['Vp'],test_XX['entro'],c=tftf,cmap='gray',alpha=0.5)
ax[0].set_yscale('log');ax[1].set_yscale('log');ax[2].set_yscale('log')
ax[0].set_title('Real');ax[1].set_title('Predict');ax[2].set_title('Not Correct')
# Out:
# Text(0.5, 1.0, 'Not Correct')

# %% [markdown]
# ## 4. 과학적인 데이터 재생산을 위해 데이터 전처리

# %% [markdown]
# 4.1. 여기서는 07to6라는 산소 이온 비율을 플라즈마 상태만으로 추정 해보겠습니다.

# %% [markdown]
# 4.2. 위와 같은 방법으로 데이터 전처리 시도

# %%
X0 = np.log10(train_XX[para])
test_X0 = np.log10(test_XX[para])

Y0 = np.log10(train_YY['O7to6']) ; test_Y0 = np.log10(test_YY['O7to6'])

train_X0,valid_X0,train_Y0,valid_Y0 = train_test_split(X0,Y0,test_size=0.2, shuffle=True, random_state=0)

reg_sc = StandardScaler()

train_X0 = reg_sc.fit_transform(train_X0)
valid_X0 = reg_sc.transform(valid_X0)
test_X0 = reg_sc.transform(test_X0)

# %% [markdown]
# ## 5. 데이터 훈련 및 결과

# %% [markdown]
# 5.1. 이온 비율은 다중 회귀를 통해서 정확한 추정을 해야하므로 딥러닝 모델에서 노드를 많이 설정합니다.

# %%
train_dt0 = tf.data.Dataset.from_tensor_slices((train_X0, train_Y0))
train_dt0 = train_dt0.shuffle(len(train_X0)).batch(batch_size=512)

# %%
reg_model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, input_dim=5, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
    ])

# %%
reg_model.compile(loss='mse', optimizer='adam', metrics=['mae'])
reg_history = reg_model.fit(train_dt0, epochs=50, verbose=2,validation_data=(valid_X0,valid_Y0))
# Out:
# Epoch 1/50
# 20/20 - 1s - loss: 0.3019 - mae: 0.4450 - val_loss: 0.1554 - val_mae: 0.3102 - 758ms/epoch - 38ms/step
# Epoch 2/50
# 20/20 - 0s - loss: 0.1374 - mae: 0.2967 - val_loss: 0.1151 - val_mae: 0.2770 - 230ms/epoch - 11ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 0.1012 - mae: 0.2551 - val_loss: 0.0858 - val_mae: 0.2353 - 166ms/epoch - 8ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 0.0789 - mae: 0.2236 - val_loss: 0.0695 - val_mae: 0.2103 - 170ms/epoch - 9ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 0.0645 - mae: 0.2008 - val_loss: 0.0594 - val_mae: 0.1937 - 228ms/epoch - 11ms/step
# Epoch 6/50
# 20/20 - 0s - loss: 0.0565 - mae: 0.1873 - val_loss: 0.0543 - val_mae: 0.1845 - 230ms/epoch - 11ms/step
# Epoch 7/50
# 20/20 - 0s - loss: 0.0528 - mae: 0.1805 - val_loss: 0.0505 - val_mae: 0.1764 - 241ms/epoch - 12ms/step
# Epoch 8/50
# 20/20 - 0s - loss: 0.0508 - mae: 0.1766 - val_loss: 0.0504 - val_mae: 0.1759 - 233ms/epoch - 12ms/step
# Epoch 9/50
# 20/20 - 0s - loss: 0.0501 - mae: 0.1750 - val_loss: 0.0490 - val_mae: 0.1727 - 172ms/epoch - 9ms/step
# Epoch 10/50
# 20/20 - 0s - loss: 0.0494 - mae: 0.1735 - val_loss: 0.0484 - val_mae: 0.1713 - 244ms/epoch - 12ms/step
# Epoch 11/50
# 20/20 - 0s - loss: 0.0490 - mae: 0.1728 - val_loss: 0.0481 - val_mae: 0.1704 - 168ms/epoch - 8ms/step
# Epoch 12/50
# 20/20 - 0s - loss: 0.0485 - mae: 0.1720 - val_loss: 0.0490 - val_mae: 0.1725 - 162ms/epoch - 8ms/step
# Epoch 13/50
# 20/20 - 0s - loss: 0.0483 - mae: 0.1717 - val_loss: 0.0477 - val_mae: 0.1695 - 232ms/epoch - 12ms/step
# Epoch 14/50
# 20/20 - 0s - loss: 0.0481 - mae: 0.1710 - val_loss: 0.0482 - val_mae: 0.1707 - 238ms/epoch - 12ms/step
# Epoch 15/50
# 20/20 - 0s - loss: 0.0478 - mae: 0.1705 - val_loss: 0.0477 - val_mae: 0.1695 - 163ms/epoch - 8ms/step
# Epoch 16/50
# 20/20 - 0s - loss: 0.0473 - mae: 0.1698 - val_loss: 0.0473 - val_mae: 0.1685 - 227ms/epoch - 11ms/step
# Epoch 17/50
# 20/20 - 0s - loss: 0.0472 - mae: 0.1696 - val_loss: 0.0472 - val_mae: 0.1683 - 229ms/epoch - 11ms/step
# Epoch 18/50
# 20/20 - 0s - loss: 0.0471 - mae: 0.1693 - val_loss: 0.0477 - val_mae: 0.1697 - 167ms/epoch - 8ms/step
# Epoch 19/50
# 20/20 - 0s - loss: 0.0469 - mae: 0.1690 - val_loss: 0.0476 - val_mae: 0.1693 - 163ms/epoch - 8ms/step
# Epoch 20/50
# 20/20 - 0s - loss: 0.0469 - mae: 0.1691 - val_loss: 0.0471 - val_mae: 0.1683 - 161ms/epoch - 8ms/step
# Epoch 21/50
# 20/20 - 0s - loss: 0.0470 - mae: 0.1693 - val_loss: 0.0470 - val_mae: 0.1680 - 163ms/epoch - 8ms/step
# Epoch 22/50
# 20/20 - 0s - loss: 0.0465 - mae: 0.1687 - val_loss: 0.0478 - val_mae: 0.1695 - 238ms/epoch - 12ms/step
# Epoch 23/50
# 20/20 - 0s - loss: 0.0466 - mae: 0.1685 - val_loss: 0.0471 - val_mae: 0.1680 - 240ms/epoch - 12ms/step
# Epoch 24/50
# 20/20 - 0s - loss: 0.0465 - mae: 0.1681 - val_loss: 0.0480 - val_mae: 0.1700 - 174ms/epoch - 9ms/step
# Epoch 25/50
# 20/20 - 0s - loss: 0.0463 - mae: 0.1682 - val_loss: 0.0463 - val_mae: 0.1664 - 163ms/epoch - 8ms/step
# Epoch 26/50
# 20/20 - 0s - loss: 0.0460 - mae: 0.1675 - val_loss: 0.0465 - val_mae: 0.1670 - 165ms/epoch - 8ms/step
# Epoch 27/50
# 20/20 - 0s - loss: 0.0461 - mae: 0.1675 - val_loss: 0.0469 - val_mae: 0.1680 - 231ms/epoch - 12ms/step
# Epoch 28/50
# 20/20 - 0s - loss: 0.0460 - mae: 0.1674 - val_loss: 0.0465 - val_mae: 0.1669 - 165ms/epoch - 8ms/step
# Epoch 29/50
# 20/20 - 0s - loss: 0.0458 - mae: 0.1670 - val_loss: 0.0461 - val_mae: 0.1657 - 233ms/epoch - 12ms/step
# Epoch 30/50
# 20/20 - 0s - loss: 0.0457 - mae: 0.1668 - val_loss: 0.0461 - val_mae: 0.1659 - 228ms/epoch - 11ms/step
# Epoch 31/50
# 20/20 - 0s - loss: 0.0456 - mae: 0.1666 - val_loss: 0.0460 - val_mae: 0.1658 - 161ms/epoch - 8ms/step
# Epoch 32/50
# 20/20 - 0s - loss: 0.0456 - mae: 0.1665 - val_loss: 0.0468 - val_mae: 0.1674 - 230ms/epoch - 12ms/step
# Epoch 33/50
# 20/20 - 0s - loss: 0.0453 - mae: 0.1660 - val_loss: 0.0460 - val_mae: 0.1655 - 164ms/epoch - 8ms/step
# Epoch 34/50
# 20/20 - 0s - loss: 0.0454 - mae: 0.1661 - val_loss: 0.0473 - val_mae: 0.1684 - 179ms/epoch - 9ms/step
# Epoch 35/50
# 20/20 - 0s - loss: 0.0456 - mae: 0.1669 - val_loss: 0.0466 - val_mae: 0.1670 - 234ms/epoch - 12ms/step
# Epoch 36/50
# 20/20 - 0s - loss: 0.0458 - mae: 0.1669 - val_loss: 0.0460 - val_mae: 0.1651 - 165ms/epoch - 8ms/step
# Epoch 37/50
# 20/20 - 0s - loss: 0.0454 - mae: 0.1663 - val_loss: 0.0461 - val_mae: 0.1659 - 229ms/epoch - 11ms/step
# Epoch 38/50
# 20/20 - 0s - loss: 0.0455 - mae: 0.1662 - val_loss: 0.0463 - val_mae: 0.1662 - 237ms/epoch - 12ms/step
# Epoch 39/50
# 20/20 - 0s - loss: 0.0455 - mae: 0.1665 - val_loss: 0.0458 - val_mae: 0.1651 - 230ms/epoch - 12ms/step
# Epoch 40/50
# 20/20 - 0s - loss: 0.0452 - mae: 0.1657 - val_loss: 0.0458 - val_mae: 0.1652 - 166ms/epoch - 8ms/step
# Epoch 41/50
# 20/20 - 0s - loss: 0.0450 - mae: 0.1653 - val_loss: 0.0468 - val_mae: 0.1666 - 163ms/epoch - 8ms/step
# Epoch 42/50
# 20/20 - 0s - loss: 0.0454 - mae: 0.1662 - val_loss: 0.0458 - val_mae: 0.1649 - 234ms/epoch - 12ms/step
# Epoch 43/50
# 20/20 - 0s - loss: 0.0449 - mae: 0.1651 - val_loss: 0.0455 - val_mae: 0.1645 - 162ms/epoch - 8ms/step
# Epoch 44/50
# 20/20 - 0s - loss: 0.0448 - mae: 0.1649 - val_loss: 0.0456 - val_mae: 0.1645 - 225ms/epoch - 11ms/step
# Epoch 45/50
# 20/20 - 0s - loss: 0.0450 - mae: 0.1654 - val_loss: 0.0458 - val_mae: 0.1649 - 225ms/epoch - 11ms/step
# Epoch 46/50
# 20/20 - 0s - loss: 0.0449 - mae: 0.1651 - val_loss: 0.0461 - val_mae: 0.1653 - 227ms/epoch - 11ms/step
# Epoch 47/50
# 20/20 - 0s - loss: 0.0449 - mae: 0.1650 - val_loss: 0.0468 - val_mae: 0.1668 - 169ms/epoch - 8ms/step
# Epoch 48/50
# 20/20 - 0s - loss: 0.0448 - mae: 0.1648 - val_loss: 0.0469 - val_mae: 0.1671 - 165ms/epoch - 8ms/step
# Epoch 49/50
# 20/20 - 0s - loss: 0.0448 - mae: 0.1648 - val_loss: 0.0470 - val_mae: 0.1674 - 236ms/epoch - 12ms/step
# Epoch 50/50
# 20/20 - 0s - loss: 0.0450 - mae: 0.1659 - val_loss: 0.0473 - val_mae: 0.1685 - 164ms/epoch - 8ms/step

# %% [markdown]
# 5.2. epoch당 MSE, MAE변화를 파악합니다.

# %%
reg_history = pd.DataFrame(reg_history.history)

fig, mae_ax = plt.subplots(figsize=(15,7))

mse_ax = mae_ax.twinx()

mae_ax.plot(reg_history['mae'], 'b',marker='o', label='train mae')
mae_ax.plot(reg_history['val_mae'], 'g',marker='o', label='val mae')

mse_ax.plot(reg_history['loss'], 'y',marker='o', label='train mse')
mse_ax.plot(reg_history['val_loss'], 'r',marker='o', label='val mse')

mae_ax.set_xlabel('epoch')
mae_ax.set_ylabel('MAE')
mse_ax.set_ylabel('MSE')

mae_ax.legend(loc='upper right')
mse_ax.legend(loc='upper center')

plt.show()

# %% [markdown]
# 5.3. 실제값과 예측값을 비교하기

# %%
mse, mae = reg_model.evaluate(test_X0, test_Y0)

reg_predictions = reg_model.predict(test_X0)

print("테스트 데이터의 mae 값: ", mae)
for i in range(10):
    print("%d 번째 데이터의 [실제값,예측값] : [%f,%f]"\
          % (i, test_Y0.iloc[i],reg_predictions[i]))
# Out:
# 188/188 [==============================] - 0s 1ms/step - loss: 0.0451 - mae: 0.1639
# 테스트 데이터의 mae 값:  0.16391697525978088
# 0 번째 데이터의 [실제값,예측값] : [-1.541241,-1.429588]
# 1 번째 데이터의 [실제값,예측값] : [-1.828186,-1.460464]
# 2 번째 데이터의 [실제값,예측값] : [-1.511858,-1.451704]
# 3 번째 데이터의 [실제값,예측값] : [-1.807237,-1.472744]
# 4 번째 데이터의 [실제값,예측값] : [-1.792150,-1.441254]
# 5 번째 데이터의 [실제값,예측값] : [-1.798603,-1.469409]
# 6 번째 데이터의 [실제값,예측값] : [-1.707412,-1.521572]
# 7 번째 데이터의 [실제값,예측값] : [-1.755896,-1.552746]
# 8 번째 데이터의 [실제값,예측값] : [-1.669383,-1.495186]
# 9 번째 데이터의 [실제값,예측값] : [-1.430415,-1.641317]

# %% [markdown]
# 5.4. 실제값과 예측값의 차이를 DataFrame으로 지정합니다.

# %%
error = pd.DataFrame(columns=["Real","Predict"])
error['Real'] = test_Y0 ; error['Predict'] = reg_predictions
error['error'] = abs(error['Real'] - error['Predict']) # 단순한 값의 차이
error['error_ratio'] = (10**error['Predict'])/(10**error['Real']) # 비율상으로 얼마나 차이가 나는 것인지

error = error.join(test_XX[para])

# %% [markdown]
# 5.5. 시간에 따라서 실제값과 예측값을 그려봅니다.

# %%
plt.figure(figsize=(10,5))
plt.plot(error['Real'],label='Real')
plt.plot(error['Predict'],label='Predict')
plt.legend(loc='upper right');plt.xticks(fontsize=10)
# Out:
# (array([730120., 730180., 730241., 730302., 730364., 730425., 730486.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
plt.figure(figsize=(10,5))
plt.plot(error['Real'],label='Real')
plt.plot(error['Predict'],label='Predict')
plt.legend(loc='upper right');plt.xticks(fontsize=10,rotation=-15)
plt.xlim(datetime(2000,1,1),datetime(2000,2,1))
# Out:
# (730120.0, 730151.0)

# %% [markdown]
# 5.6. 실제값과 예측값이 1대1 대응을 하는 것인지 y=x 그래프를 통해 파악합니다.
# - 회색선은 값 차이가 0.25이상의 경계선을 의미합니다.

# %%
sns.jointplot("Real","Predict",error,kind='hex')
plt.plot([-2,0],[-2,0],linestyle='--',linewidth=2,color='red')
plt.plot([-2,0],[-1.75,0.25],linestyle=':',linewidth=2,color='grey')
plt.plot([-2,0],[-2.25,-0.25],linestyle=':',linewidth=2,color='grey')
plt.xlim(-2,0);plt.ylim(-2,0)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (-2.0, 0.0)

# %% [markdown]
# 5.6.1 실제값중에서 어떤 곳에서 가장 많은 에러를 발생하는 것인지 조사합니다.
# - 빨간 점선은 0.25이상의 경계선을 나타냅니다.
# - 전체 데이터중에서 에러값이 0.25이하인 데이터의 비율을 파악합니다.

# %%
percen = 100*error[error['error'] <= 0.25]['error'].count()/error['error'].count()
print("Error 0.25이하 : {}%".format(round(percen,2)))
sns.jointplot("Real","error",error,kind='hex')
plt.axhline(0.25,linestyle='--',linewidth=2,color='red')
plt.xlim(-2,0);plt.ylim(0,1)
# Out:
# Error 0.25이하 : 78.11%
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (0.0, 1.0)

# %% [markdown]
# 5.6.2. 실제값중에서 어떤 곳에서 가장 많은 에러를 발생하는 것인지 히스토그램을 그려봅니다.
# - 빨간 히스토그램은 에러값 0.25이상인 데이터의 히스토그램을 나타냅니다.

# %%
plt.figure(figsize=(10,10))

plt.hist(error['Real'],bins=50,label='Real')
plt.hist(error[error['error'] > 0.25]['Real'],bins=50,color='red',label='Error > 0.25')
plt.legend()

# %% [markdown]
# # <결과>
#
# 1. 플라즈마 이진분류에서 약 82%의 정확도를 보여주고 있으며 서로 겹쳐지는 영역에서 제대로 분류하지 못하는 모습을 보입니다.
#
# 2. 다른 변수도 훈련 데이터에 넣어봤지만 82%이상의 정확도는 보여주지 못합니다.
#
# 3. Real 데이터의 분류는 2009년에 플라즈마의 속도와 플라즈마의 산소 이온 비율(Oxygen Ratio)을 통해 Zhou et al. 2008에서 분류 됐습니다.
#
# 4. 플라즈마 상태만을 이용하여 과학적으로 의미가 있는 이온 비율(산소 이온 비율)을 생산 해보았습니다. 에러값이 작은 0.25이하의 비율은 약 78%이며, 대부분 데이터가 없는 부분에서 잘 추측하지 못하는 것을 확인할 수 있었습니다.
#
# 5. 데이터의 비율을 증가시키고 추가적으로 데이터 전처리 과정에서 좀 더 깔끔하게 처리할 수 있다면 좀 더 좋은 성능을 보일 수 있을 것이며 추가적인 연구 과정에서도 이용할 수 있을 것으로 판단됩니다.
